# %%
import bs4 as bs
import numpy as np
import pandas as pd
import requests
import yfinance as yf
import datetime as dt
import requests
import pickle
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
with open("IndexHistory.pickle","rb") as f:
    index_history = pickle.load(f)
with open("StockHistory.pickle","rb") as f:
    stock_history = pickle.load(f)

# %%
for index_, index_hist_ in index_history.items():
    if (str(index_hist_.index.values[-1]) == '2020-05-29'):
        print("First")
    elif (str(index_hist_.index.values[-1]) == '2020-05-29T00:00:00.000000000'):
        print("Second")
    print(index_hist_.iloc[-1].name.strftime('%m/%d/%Y'))
# Out:
# Second
# 05/29/2020
# Second
# 05/29/2020
# Second
# 05/29/2020
# Second
# 05/29/2020

# %%
stock_history
# Out:
# {'SP500':             Adj Close                                                \
#                      A        AAL         AAP        AAPL       ABBV
#  Date
#  2010-01-04  20.436504   4.496876   39.223591   26.466835        NaN
#  2010-01-05  20.214516   5.005957   38.990475   26.512596        NaN
#  2010-01-06  20.142689   4.798555   39.330433   26.090879        NaN
#  2010-01-07  20.116571   4.939965   39.320717   26.042646        NaN
#  2010-01-08  20.110041   4.845690   39.476143   26.215786        NaN
#  ...               ...        ...         ...         ...        ...
#  2020-05-26  86.129997  11.140000  135.338547  316.730011  90.709999
#  2020-05-27  86.180000  11.980000  141.457642  318.109985  89.980003
#  2020-05-28  86.690002  10.980000  138.193466  318.250000  90.029999
#  2020-05-29  88.139999  10.500000  139.071899  317.940002  92.669998
#  2020-06-01        NaN        NaN         NaN         NaN        NaN
#
# ...
